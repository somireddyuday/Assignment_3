# %%
from tqdm import tqdm

import glob
import ntpath
import cv2

from sklearn.metrics.pairwise import cosine_similarity
import scipy as sc
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.applications.vgg19 import preprocess_input
from tensorflow.keras.models import Model

import io
import bson
import matplotlib.pyplot as plt
from skimage.io import imread   # or, whatever image library you prefer
import multiprocessing as mp      # will come in handy due to the size of the data
from PIL import Image

# %%
import glob
image_paths = glob.glob(r'C:\Users\somir\Desktop\ADM_assignment_3\Newfolder_1\input_Images\*.jpg')

# %%
images = {}
for image_path in image_paths:
    image = cv2.imread(image_path, 3)
    b,g,r = cv2.split(image)           # Splitting the RGB Channels of the image
    image = cv2.merge([r,g,b]) 
    image = cv2.resize(image, (200, 200))
    images[image_path] = image

# %%
n_col = 8
n_row = 8
f, ax = plt.subplots(n_row, n_col, figsize=(16, 8))
for i in range(n_row):
    for j in range(n_col):
        ax[i, j].imshow(list(images.values())[n_col*i + j])
        ax[i, j].set_axis_off()

# %%
def load_image(image):
    image = plt.imread(image)
    img = tf.image.convert_image_dtype(image, tf.float32)
    img = tf.image.resize(img, [400, 400])
    img = img[tf.newaxis, :] # shape -> (batch_size, h, w, d)
    return img

# content layers describe the image subject
content_layers = ['block5_conv2'] 

# style layers describe the image style
# we exclude the upper level layes to focus on small-size style details
style_layers = [ 
        'block1_conv1',
        'block2_conv1',
        'block3_conv1', 
        #'block4_conv1', 
        #'block5_conv1'
    ] 

def selected_layers_model(layer_names, baseline_model):
    outputs = [baseline_model.get_layer(name).output for name in layer_names]
    model = Model([vgg.input], outputs)
    return model

# style embedding is computed as concatenation of gram matrices of the style layers
def gram_matrix(input_tensor):
    result = tf.linalg.einsum('bijc,bijd->bcd', input_tensor, input_tensor)
    input_shape = tf.shape(input_tensor)
    num_locations = tf.cast(input_shape[1]*input_shape[2], tf.float32)
    return result/(num_locations)

class StyleModel(tf.keras.models.Model):
    def __init__(self, style_layers, content_layers):
        super(StyleModel, self).__init__()
        self.vgg =  selected_layers_model(style_layers + content_layers, vgg)
        self.style_layers = style_layers
        self.content_layers = content_layers
        self.num_style_layers = len(style_layers)
        self.vgg.trainable = False

    def call(self, inputs):
        # scale back the pixel values
        inputs = inputs*255.0
        # preprocess them with respect to VGG19 stats
        preprocessed_input = preprocess_input(inputs)
        # pass through the reduced network
        outputs = self.vgg(preprocessed_input)
        # segregate the style and content representations
        style_outputs, content_outputs = (outputs[:self.num_style_layers],
                                          outputs[self.num_style_layers:])

        # calculate the gram matrix for each layer
        style_outputs = [gram_matrix(style_output)
                         for style_output in style_outputs]

        # assign the content representation and gram matrix in
        # a layer by layer fashion in dicts
        content_dict = {content_name:value
                        for content_name, value
                        in zip(self.content_layers, content_outputs)}

        style_dict = {style_name:value
                      for style_name, value
                      in zip(self.style_layers, style_outputs)}

        return {'content':content_dict, 'style':style_dict}

vgg = tf.keras.applications.VGG19(include_top=False, weights='imagenet')

def image_to_style(image_tensor):
    extractor = StyleModel(style_layers, content_layers)
    return extractor(image_tensor)['style']

def style_to_vec(style):
    # concatenate gram matrics in a flat vector
    return np.hstack([np.ravel(s) for s in style.values()]) 
    
# compute styles
image_style_embeddings = {}
for image_path in tqdm(image_paths[:500]): 
    image_tensor = load_image(image_path)
    style = style_to_vec( image_to_style(image_tensor) )
    image_style_embeddings[image_path] = style
# Out:
# 100%|██████████| 500/500 [31:40<00:00,  3.80s/it]

# %%
def search_by_style_display(reference_image, max_results=10):
    v0 = image_style_embeddings[reference_image]
    distances = {}
    for k,v in image_style_embeddings.items():
        d = sc.spatial.distance.cosine(v0, v)
        distances[k] = d

    sorted_neighbors = sorted(distances.items(), key=lambda x: x[1], reverse=False)
    
    f, ax = plt.subplots(1, max_results, figsize=(16, 8))
    for i, img in enumerate(sorted_neighbors[:max_results]):
        ax[i].imshow(images[img[0]])
        ax[i].set_axis_off()
    
    plt.show()

# %%
search_by_style_display(r'C:\Users\somir\Desktop\ADM_assignment_3\Newfolder_1\input_Images\MEN_Denim_id_0000008903_3_back.jpg') #227,72

# %%
def search_by_style(reference_image, max_results=10):
    v0 = image_style_embeddings[reference_image]
    distances = {}
    for k,v in image_style_embeddings.items():
        d = sc.spatial.distance.cosine(v0, v)
        distances[k] = d

    sorted_neighbors = sorted(distances.items(), key=lambda x: x[1], reverse=False)
    return sorted_neighbors[:11]

# %%
search_by_style(r'C:\Users\somir\Desktop\ADM_assignment_3\Newfolder_1\input_Images\MEN_Denim_id_0000008903_3_back.jpg')
# Out:
# [('C:\\Users\\somir\\Desktop\\ADM_assignment_3\\Newfolder_1\\input_Images\\MEN_Denim_id_0000008903_3_back.jpg',
#   0.0),
#  ('C:\\Users\\somir\\Desktop\\ADM_assignment_3\\Newfolder_1\\input_Images\\MEN_Denim_id_0000008903_1_front.jpg',
#   0.0015458464622497559),
#  ('C:\\Users\\somir\\Desktop\\ADM_assignment_3\\Newfolder_1\\input_Images\\MEN_Denim_id_0000119803_1_front.jpg',
#   0.003471672534942627),
#  ('C:\\Users\\somir\\Desktop\\ADM_assignment_3\\Newfolder_1\\input_Images\\MEN_Denim_id_0000119803_3_back.jpg',
#   0.00396275520324707),
#  ('C:\\Users\\somir\\Desktop\\ADM_assignment_3\\Newfolder_1\\input_Images\\MEN_Denim_id_0000093805_3_back.jpg',
#   0.0048081278800964355),
#  ('C:\\Users\\somir\\Desktop\\ADM_assignment_3\\Newfolder_1\\input_Images\\MEN_Denim_id_0000582601_7_additional.jpg',
#   0.0067206621170043945),
#  ('C:\\Users\\somir\\Desktop\\ADM_assignment_3\\Newfolder_1\\input_Images\\MEN_Denim_id_0000480701_3_back.jpg',
#   0.00823676586151123),
#  ('C:\\Users\\somir\\Desktop\\ADM_assignment_3\\Newfolder_1\\input_Images\\MEN_Denim_id_0000008926_3_back.jpg',
#   0.008389651775360107),
#  ('C:\\Users\\somir\\Desktop\\ADM_assignment_3\\Newfolder_1\\input_Images\\MEN_Denim_id_0000325201_1_front.jpg',
#   0.00843203067779541),
#  ('C:\\Users\\somir\\Desktop\\ADM_assignment_3\\Newfolder_1\\input_Images\\MEN_Jackets_Vests_id_0000009404_3_back.jpg',
#   0.009246885776519775),
#  ('C:\\Users\\somir\\Desktop\\ADM_assignment_3\\Newfolder_1\\input_Images\\MEN_Denim_id_0000093805_2_side.jpg',
#   0.009678184986114502)]

# %%
x = []
for image_name in tqdm(images.keys()):
    z = search_by_style(image_name)
    x.append(z)
    #print(len(x))
    if len(x) == 500:
      break
# Out:
#   1%|          | 499/45359 [55:42<83:28:48,  6.70s/it]

# %%
y = pd.DataFrame(x)
y
# Out:
#                                                     0   \
# 0    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 1    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 2    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 3    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 4    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# ..                                                 ...
# 495  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 496  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 497  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 498  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 499  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
#
#                                                     1   \
# 0    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 1    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 2    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 3    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 4    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# ..                                                 ...
# 495  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 496  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 497  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 498  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 499  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
#
#                                                     2   \
# 0    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 1    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 2    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 3    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 4    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# ..                                                 ...
# 495  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 496  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 497  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 498  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 499  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
#
#                                                     3   \
# 0    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 1    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 2    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 3    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 4    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# ..                                                 ...
# 495  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 496  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 497  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 498  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 499  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
#
#                                                     4   \
# 0    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 1    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 2    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 3    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 4    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# ..                                                 ...
# 495  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 496  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 497  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 498  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 499  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
#
#                                                     5   \
# 0    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 1    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 2    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 3    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 4    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# ..                                                 ...
# 495  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 496  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 497  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 498  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 499  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
#
#                                                     6   \
# 0    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 1    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 2    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 3    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 4    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# ..                                                 ...
# 495  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 496  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 497  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 498  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 499  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
#
#                                                     7   \
# 0    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 1    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 2    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 3    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 4    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# ..                                                 ...
# 495  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 496  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 497  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 498  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 499  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
#
#                                                     8   \
# 0    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 1    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 2    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 3    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 4    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# ..                                                 ...
# 495  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 496  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 497  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 498  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 499  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
#
#                                                     9   \
# 0    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 1    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 2    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 3    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 4    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# ..                                                 ...
# 495  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 496  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 497  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 498  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 499  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
#
#                                                     10
# 0    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 1    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 2    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 3    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 4    (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# ..                                                 ...
# 495  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 496  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 497  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 498  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
# 499  (C:\Users\somir\Desktop\ADM_assignment_3\Newfo...
#
# [500 rows x 11 columns]

# %%
def test(neigh):
  return neigh[0]

# %%
z = y.applymap(test)
z
# Out:
#                                                     0   \
# 0    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 1    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 2    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 3    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 4    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# ..                                                 ...
# 495  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 496  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 497  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 498  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 499  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
#
#                                                     1   \
# 0    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 1    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 2    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 3    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 4    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# ..                                                 ...
# 495  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 496  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 497  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 498  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 499  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
#
#                                                     2   \
# 0    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 1    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 2    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 3    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 4    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# ..                                                 ...
# 495  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 496  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 497  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 498  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 499  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
#
#                                                     3   \
# 0    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 1    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 2    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 3    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 4    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# ..                                                 ...
# 495  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 496  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 497  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 498  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 499  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
#
#                                                     4   \
# 0    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 1    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 2    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 3    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 4    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# ..                                                 ...
# 495  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 496  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 497  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 498  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 499  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
#
#                                                     5   \
# 0    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 1    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 2    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 3    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 4    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# ..                                                 ...
# 495  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 496  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 497  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 498  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 499  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
#
#                                                     6   \
# 0    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 1    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 2    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 3    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 4    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# ..                                                 ...
# 495  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 496  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 497  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 498  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 499  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
#
#                                                     7   \
# 0    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 1    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 2    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 3    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 4    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# ..                                                 ...
# 495  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 496  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 497  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 498  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 499  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
#
#                                                     8   \
# 0    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 1    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 2    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 3    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 4    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# ..                                                 ...
# 495  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 496  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 497  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 498  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 499  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
#
#                                                     9   \
# 0    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 1    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 2    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 3    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 4    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# ..                                                 ...
# 495  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 496  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 497  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 498  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 499  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
#
#                                                     10
# 0    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 1    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 2    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 3    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 4    C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# ..                                                 ...
# 495  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 496  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 497  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 498  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
# 499  C:\Users\somir\Desktop\ADM_assignment_3\Newfol...
#
# [500 rows x 11 columns]

# %%
z.to_csv(r'C:\Users\somir\Desktop\ADM_assignment_3\Newfolder_1\Artistic.csv')
